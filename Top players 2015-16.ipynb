# %%
import pandas as pd
import seaborn as sns                       
import matplotlib.pyplot as plt     
import matplotlib as mpl
import os
sns.set(style="ticks")
# %matplotlib inline     
sns.set(color_codes=True)

# %%
players = pd.read_csv('players-2015-to-2016-stats.csv')
players
# Out:
#                           full_name  age   birthday birthday_GMT  \
# 0                   Aaron Cresswell   32  629683200   12/15/1989
# 1                      Aaron Lennon   34  545529600    4/16/1987
# 2                      Aaron Ramsey   31  662169600   12/26/1990
# 3                 Abdul Rahman Baba   27  773107200     7/2/1994
# 4                       Ádám Bogdán   34  559699200    9/27/1987
# ..                              ...  ...        ...          ...
# 639                Yohan Benalouane   34  543888000    3/28/1987
# 640                    Yohan Cabaye   35  506044800    1/14/1986
# 641                   Younes Kaboul   36  505180800     1/4/1986
# 642  Youssouf Chafiq Mulumbu Ngangu   34  538531200    1/25/1987
# 643                Łukasz Fabiański   36  482630400    4/18/1985
#
#              league     season    position     Current_Club  \
# 0    Premier League  2015/2016    Defender  West Ham United
# 1    Premier League  2015/2016  Midfielder          Everton
# 2    Premier League  2015/2016  Midfielder          Arsenal
# 3    Premier League  2015/2016    Defender          Chelsea
# 4    Premier League  2015/2016  Goalkeeper        Liverpool
# ..              ...        ...         ...              ...
# 639  Premier League  2015/2016    Defender   Leicester City
# 640  Premier League  2015/2016  Midfielder   Crystal Palace
# 641  Premier League  2015/2016    Defender       Sunderland
# 642  Premier League  2015/2016  Midfielder     Norwich City
# 643  Premier League  2015/2016  Goalkeeper     Swansea City
#
#      minutes_played_overall  minutes_played_home  ...  \
# 0                      3315                 1620  ...
# 1                      1538                  654  ...
# 2                      2623                 1275  ...
# 3                      1017                  495  ...
# 4                       180                    0  ...
# ..                      ...                  ...  ...
# 639                      64                   15  ...
# 640                    2703                 1415  ...
# 641                    2009                  962  ...
# 642                     370                   90  ...
# 643                    3330                 1620  ...
#
#      conceded_per_90_overall min_per_conceded_overall  min_per_match  \
# 0                       1.30                       69             90
# 1                       1.40                       64             62
# 2                       0.86                      105             85
# 3                       0.97                       92             68
# 4                       2.00                       45             90
# ..                       ...                      ...            ...
# 639                     1.41                       64             16
# 640                     1.03                       87             82
# 641                     1.21                       74             87
# 642                     1.95                       46             53
# 643                     1.32                       68             90
#
#      min_per_card_overall  min_per_assist_overall  cards_per_90_overall  \
# 0                    3315                     829                  0.03
# 1                    1538                       0                  0.06
# 2                     656                     656                  0.14
# 3                    1017                    1017                  0.09
# 4                       0                       0                  0.00
# ..                    ...                     ...                   ...
# 639                    64                       0                  1.41
# 640                   386                    2703                  0.23
# 641                   402                    2009                  0.22
# 642                   370                       0                  0.24
# 643                  3330                    3330                  0.03
#
#      rank_in_league_top_attackers  rank_in_league_top_midfielders  \
# 0                             216                             136
# 1                              66                             281
# 2                             110                              98
# 3                             298                             156
# 4                              -1                              -1
# ..                            ...                             ...
# 639                            -1                              -1
# 640                           111                             231
# 641                           322                             219
# 642                           281                             323
# 643                           409                             243
#
#      rank_in_league_top_defenders  rank_in_club_top_scorer
# 0                             103                       10
# 1                              -1                        4
# 2                              -1                        4
# 3                              42                       24
# 4                              -1                       31
# ..                            ...                      ...
# 639                            -1                       18
# 640                            -1                        3
# 641                            82                       19
# 642                            -1                       15
# 643                           106                       11
#
# [644 rows x 47 columns]

# %%
players.drop(['birthday', 'birthday_GMT','nationality' ,'minutes_played_overall', 'minutes_played_home', 'minutes_played_away',
             'goals_away','assists_away','goals_per_90_home','min_per_goal_overall','age','position','league','rank_in_league_top_midfielders',
             'appearances_home','appearances_away','goals_home','assists_home', 'penalty_goals','penalty_misses',
             'conceded_overall','conceded_home','conceded_away','goals_involved_per_90_overall',
             'assists_per_90_overall','goals_per_90_overall','goals_per_90_away','conceded_per_90_overall',
             'min_per_conceded_overall','min_per_match','min_per_card_overall','min_per_assist_overall',
             'cards_per_90_overall','rank_in_league_top_attackers','rank_in_league_top_defenders',
             'rank_in_club_top_scorer','clean_sheets_overall','clean_sheets_home','clean_sheets_away'], axis=1, inplace=True)

# %%
players
# Out:
#                           full_name     season     Current_Club  \
# 0                   Aaron Cresswell  2015/2016  West Ham United
# 1                      Aaron Lennon  2015/2016          Everton
# 2                      Aaron Ramsey  2015/2016          Arsenal
# 3                 Abdul Rahman Baba  2015/2016          Chelsea
# 4                       Ádám Bogdán  2015/2016        Liverpool
# ..                              ...        ...              ...
# 639                Yohan Benalouane  2015/2016   Leicester City
# 640                    Yohan Cabaye  2015/2016   Crystal Palace
# 641                   Younes Kaboul  2015/2016       Sunderland
# 642  Youssouf Chafiq Mulumbu Ngangu  2015/2016     Norwich City
# 643                Łukasz Fabiański  2015/2016     Swansea City
#
#      appearances_overall  goals_overall  assists_overall  \
# 0                     37              2                4
# 1                     25              5                0
# 2                     31              5                4
# 3                     15              0                1
# 4                      2              0                0
# ..                   ...            ...              ...
# 639                    4              0                0
# 640                   33              5                1
# 641                   23              0                1
# 642                    7              0                0
# 643                   37              0                1
#
#      yellow_cards_overall  red_cards_overall
# 0                       1                  0
# 1                       1                  0
# 2                       4                  0
# 3                       1                  0
# 4                       0                  0
# ..                    ...                ...
# 639                     1                  0
# 640                     7                  0
# 641                     5                  1
# 642                     1                  0
# 643                     1                  0
#
# [644 rows x 8 columns]

# %%
players.isnull().sum()
# Out:
# full_name               0
# season                  0
# Current_Club            0
# appearances_overall     0
# goals_overall           0
# assists_overall         0
# yellow_cards_overall    0
# red_cards_overall       0
# dtype: int64

# %%
Figure= players.groupby(['season'])[['goals_overall']].count()
Figure
# Out:
#            goals_overall
# season
# 2015/2016            644

# %%
top_player = players.nlargest(2,['goals_overall'])
top_player
# Out:
#        full_name     season       Current_Club  appearances_overall  \
# 228   Harry Kane  2015/2016  Tottenham Hotspur                   38
# 266  Jamie Vardy  2015/2016     Leicester City                   36
#
#      goals_overall  assists_overall  yellow_cards_overall  red_cards_overall
# 228             25                1                     5                  0
# 266             24                6                     7                  1

# %%
top_player.index=["Harry Kane", "Jamie Vardy"]
plt.figure(figsize=(10,6))
top_player.plot(kind='bar')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5),fontsize=13)
plt.title("Top 2 Players depending on the Overall goals from 2015-2016",weight='bold')
plt.xlabel("Players",weight='bold')
plt.ylabel("Points",weight='bold')
plt.savefig("Top 2 Players depending on the Overall goals from 2015-2016.jpg")
  
# Saving figure by changing parameter values
plt.savefig("Top 2 Players depending on the Overall goals from 2015-2016", bbox_inches="tight",
            pad_inches=0.3, transparent=False)

# %%
players1 = pd.read_csv('england-premier-league-players-2016-to-2017-stats.csv')
players1
# Out:
#               full_name  age   birthday birthday_GMT          league  \
# 0       Aaron Cresswell   32  629683200   12/15/1989  Premier League
# 1          Aaron Lennon   34  545529600    4/16/1987  Premier League
# 2        Aaron Ramsdale   23  895104000    5/14/1998  Premier League
# 3          Aaron Ramsey   31  662169600   12/26/1990  Premier League
# 4     Aaron Wan-Bissaka   24  880502400   11/26/1997  Premier League
# ..                  ...  ...        ...          ...             ...
# 615       Younes Kaboul   36  505180800     1/4/1986  Premier League
# 616    Zachary Dearnley   23  906940800    9/28/1998  Premier League
# 617         Zeki Fryers   29  715996800     9/9/1992  Premier League
# 618  Zlatan Ibrahimović   40  370915200    10/3/1981  Premier League
# 619    Łukasz Fabiański   36  482630400    4/18/1985  Premier League
#
#         season    position       Current_Club  minutes_played_overall  \
# 0    2016/2017    Defender    West Ham United                    2117
# 1    2016/2017  Midfielder            Everton                     509
# 2    2016/2017  Goalkeeper    AFC Bournemouth                       0
# 3    2016/2017  Midfielder            Arsenal                    1229
# 4    2016/2017  Midfielder     Crystal Palace                       0
# ..         ...         ...                ...                     ...
# 615  2016/2017    Defender            Watford                    1915
# 616  2016/2017  Midfielder  Manchester United                       0
# 617  2016/2017    Defender     Crystal Palace                     180
# 618  2016/2017     Forward  Manchester United                    2437
# 619  2016/2017  Goalkeeper       Swansea City                    3330
#
#      minutes_played_home  ...  conceded_per_90_overall  \
# 0                    940  ...                     1.40
# 1                    302  ...                     0.71
# 2                      0  ...                     0.00
# 3                    518  ...                     1.39
# 4                      0  ...                     0.00
# ..                   ...  ...                      ...
# 615                  945  ...                     1.64
# 616                    0  ...                     0.00
# 617                   60  ...                     2.00
# 618                 1267  ...                     0.74
# 619                 1620  ...                     1.70
#
#     min_per_conceded_overall  min_per_match  min_per_card_overall  \
# 0                         64             81                   529
# 1                        127             46                     0
# 2                          0              0                     0
# 3                         65             53                   410
# 4                          0              0                     0
# ..                       ...            ...                   ...
# 615                       55             83                   958
# 616                        0              0                     0
# 617                       45             23                     0
# 618                      122             87                   348
# 619                       53             90                  3330
#
#      min_per_assist_overall  cards_per_90_overall  \
# 0                      1059                  0.17
# 1                       509                  0.00
# 2                         0                  0.00
# 3                       307                  0.22
# 4                         0                  0.00
# ..                      ...                   ...
# 615                       0                  0.09
# 616                       0                  0.00
# 617                     180                  0.00
# 618                     487                  0.26
# 619                       0                  0.03
#
#      rank_in_league_top_attackers  rank_in_league_top_midfielders  \
# 0                             293                             160
# 1                             330                              70
# 2                              -1                              -1
# 3                             187                              21
# 4                              -1                              -1
# ..                            ...                             ...
# 615                           167                             414
# 616                            -1                              -1
# 617                            -1                              -1
# 618                             8                              69
# 619                           317                             325
#
#      rank_in_league_top_defenders  rank_in_club_top_scorer
# 0                              95                       26
# 1                              -1                       25
# 2                              -1                       -1
# 3                              -1                       13
# 4                              -1                       -1
# ..                            ...                      ...
# 615                           138                        9
# 616                            -1                       -1
# 617                            -1                       19
# 618                            -1                        1
# 619                           145                       27
#
# [620 rows x 47 columns]

# %%
players1.drop(['birthday', 'birthday_GMT','nationality' ,'minutes_played_overall', 'minutes_played_home', 'minutes_played_away',
             'goals_away','assists_away','goals_per_90_home','min_per_goal_overall','age','position','league','rank_in_league_top_midfielders',
             'appearances_home','appearances_away','goals_home','assists_home', 'penalty_goals','penalty_misses',
             'conceded_overall','conceded_home','conceded_away','goals_involved_per_90_overall',
             'assists_per_90_overall','goals_per_90_overall','goals_per_90_away','conceded_per_90_overall',
             'min_per_conceded_overall','min_per_match','min_per_card_overall','min_per_assist_overall',
             'cards_per_90_overall','rank_in_league_top_attackers','rank_in_league_top_defenders',
             'rank_in_club_top_scorer','clean_sheets_overall','clean_sheets_home','clean_sheets_away'], axis=1, inplace=True)

# %%
players1
# Out:
#               full_name     season       Current_Club  appearances_overall  \
# 0       Aaron Cresswell  2016/2017    West Ham United                   26
# 1          Aaron Lennon  2016/2017            Everton                   11
# 2        Aaron Ramsdale  2016/2017    AFC Bournemouth                    0
# 3          Aaron Ramsey  2016/2017            Arsenal                   23
# 4     Aaron Wan-Bissaka  2016/2017     Crystal Palace                    0
# ..                  ...        ...                ...                  ...
# 615       Younes Kaboul  2016/2017            Watford                   23
# 616    Zachary Dearnley  2016/2017  Manchester United                    0
# 617         Zeki Fryers  2016/2017     Crystal Palace                    8
# 618  Zlatan Ibrahimović  2016/2017  Manchester United                   28
# 619    Łukasz Fabiański  2016/2017       Swansea City                   37
#
#      goals_overall  assists_overall  yellow_cards_overall  red_cards_overall
# 0                0                2                     4                  1
# 1                0                1                     0                  0
# 2                0                0                     0                  0
# 3                1                4                     3                  0
# 4                0                0                     0                  0
# ..             ...              ...                   ...                ...
# 615              2                0                     2                  0
# 616              0                0                     0                  0
# 617              0                1                     0                  0
# 618             17                5                     7                  0
# 619              0                0                     1                  0
#
# [620 rows x 8 columns]

# %%
top_player1 = players1.nlargest(2,['goals_overall'])
top_player1
# Out:
#          full_name     season       Current_Club  appearances_overall  \
# 237     Harry Kane  2016/2017  Tottenham Hotspur                   30
# 521  Romelu Lukaku  2016/2017            Everton                   37
#
#      goals_overall  assists_overall  yellow_cards_overall  red_cards_overall
# 237             29                7                     3                  0
# 521             25                6                     3                  0

# %%
top_player1.index=["Harry Kane", "Romelu Lukaku"]
plt.figure(figsize=(20,18))
top_player1.plot(kind='bar')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5),fontsize=13)
plt.title("Top 2 Players depending on the Overall goals from 2016-2017",weight='bold')
plt.xlabel("Players",weight='bold')
plt.ylabel("Points",weight='bold')
plt.savefig("Top 2 Players depending on the Overall goals from 2016-2017.jpg")
  
# Saving figure by changing parameter values
plt.savefig("Top 2 Players depending on the Overall goals from 2016-2017", bbox_inches="tight",
            pad_inches=0.3, transparent=False)

# %%
players2 = pd.read_csv('england-premier-league-players-2017-to-2018-stats.csv')
players2
# Out:
#               full_name  age   birthday birthday_GMT          league  \
# 0       Aaron Cresswell   32  629683200   12/15/1989  Premier League
# 1          Aaron Lennon   34  545529600    4/16/1987  Premier League
# 2            Aaron Mooy   31  653356800    9/15/1990  Premier League
# 3        Aaron Ramsdale   23  895104000    5/14/1998  Premier League
# 4          Aaron Ramsey   31  662169600   12/26/1990  Premier League
# ..                  ...  ...        ...          ...             ...
# 597    Yohan Benalouane   34  543888000    3/28/1987  Premier League
# 598        Yohan Cabaye   35  506044800    1/14/1986  Premier League
# 599       Younes Kaboul   36  505180800     1/4/1986  Premier League
# 600  Zlatan Ibrahimović   40  370915200    10/3/1981  Premier League
# 601    Łukasz Fabiański   36  482630400    4/18/1985  Premier League
#
#         season    position       Current Club  minutes_played_overall  \
# 0    2017/2018    Defender    West Ham United                    3073
# 1    2017/2018  Midfielder            Burnley                    1918
# 2    2017/2018  Midfielder  Huddersfield Town                    3070
# 3    2017/2018  Goalkeeper    AFC Bournemouth                       0
# 4    2017/2018  Midfielder            Arsenal                    1848
# ..         ...         ...                ...                     ...
# 597  2017/2018    Defender     Leicester City                      90
# 598  2017/2018  Midfielder     Crystal Palace                    2388
# 599  2017/2018    Defender            Watford                     151
# 600  2017/2018     Forward  Manchester United                     103
# 601  2017/2018  Goalkeeper       Swansea City                    3420
#
#      minutes_played_home  ...  conceded_per_90_overall  \
# 0                   1604  ...                     1.67
# 1                    927  ...                     1.31
# 2                   1635  ...                     1.50
# 3                      0  ...                     0.00
# 4                    976  ...                     1.07
# ..                   ...  ...                      ...
# 597                   90  ...                     2.00
# 598                 1157  ...                     1.36
# 599                   90  ...                     1.79
# 600                  101  ...                     1.75
# 601                 1710  ...                     1.39
#
#     min_per_conceded_overall  min_per_match  min_per_card_overall  \
# 0                         54             85                   439
# 1                         69             66                   959
# 2                         60             85                   614
# 3                          0              0                     0
# 4                         84             77                     0
# ..                       ...            ...                   ...
# 597                       45             90                     0
# 598                       66             77                   341
# 599                       50             76                     0
# 600                       52             21                     0
# 601                       65             90                     0
#
#      min_per_assist_overall  cards_per_90_overall  \
# 0                       439                  0.21
# 1                       959                  0.09
# 2                      1023                  0.15
# 3                         0                  0.00
# 4                       231                  0.00
# ..                      ...                   ...
# 597                       0                  0.00
# 598                    2388                  0.26
# 599                       0                  0.00
# 600                       0                  0.00
# 601                       0                  0.00
#
#      rank_in_league_top_attackers  rank_in_league_top_midfielders  \
# 0                             233                              55
# 1                             268                             144
# 2                             136                             141
# 3                              -1                              -1
# 4                              44                               8
# ..                            ...                             ...
# 597                            -1                              -1
# 598                           244                             221
# 599                            -1                              -1
# 600                            -1                              -1
# 601                           320                             393
#
#      rank_in_league_top_defenders  rank_in_club_top_scorer
# 0                             164                       12
# 1                              -1                       15
# 2                              -1                        3
# 3                              -1                       -1
# 4                              -1                        3
# ..                            ...                      ...
# 597                            -1                       13
# 598                            -1                       12
# 599                            -1                       25
# 600                            -1                       14
# 601                           102                       19
#
# [602 rows x 47 columns]

# %%
players2.drop(['birthday', 'birthday_GMT','nationality' ,'minutes_played_overall', 'minutes_played_home', 'minutes_played_away',
             'goals_away','assists_away','goals_per_90_home','min_per_goal_overall','age','position','league','rank_in_league_top_midfielders',
             'appearances_home','appearances_away','goals_home','assists_home', 'penalty_goals','penalty_misses',
             'conceded_overall','conceded_home','conceded_away','goals_involved_per_90_overall',
             'assists_per_90_overall','goals_per_90_overall','goals_per_90_away','conceded_per_90_overall',
             'min_per_conceded_overall','min_per_match','min_per_card_overall','min_per_assist_overall',
             'cards_per_90_overall','rank_in_league_top_attackers','rank_in_league_top_defenders',
             'rank_in_club_top_scorer','clean_sheets_overall','clean_sheets_home','clean_sheets_away'], axis=1, inplace=True)

# %%
players2
# Out:
#               full_name     season       Current Club  appearances_overall  \
# 0       Aaron Cresswell  2017/2018    West Ham United                   36
# 1          Aaron Lennon  2017/2018            Burnley                   29
# 2            Aaron Mooy  2017/2018  Huddersfield Town                   36
# 3        Aaron Ramsdale  2017/2018    AFC Bournemouth                    0
# 4          Aaron Ramsey  2017/2018            Arsenal                   24
# ..                  ...        ...                ...                  ...
# 597    Yohan Benalouane  2017/2018     Leicester City                    1
# 598        Yohan Cabaye  2017/2018     Crystal Palace                   31
# 599       Younes Kaboul  2017/2018            Watford                    2
# 600  Zlatan Ibrahimović  2017/2018  Manchester United                    5
# 601    Łukasz Fabiański  2017/2018       Swansea City                   38
#
#      goals_overall  assists_overall  yellow_cards_overall  red_cards_overall
# 0                1                7                     7                  0
# 1                0                2                     2                  0
# 2                4                3                     5                  0
# 3                0                0                     0                  0
# 4                7                8                     0                  0
# ..             ...              ...                   ...                ...
# 597              0                0                     0                  0
# 598              0                1                     7                  0
# 599              0                0                     0                  0
# 600              0                0                     0                  0
# 601              0                0                     0                  0
#
# [602 rows x 8 columns]

# %%
top_player2 = players2.nlargest(2,['goals_overall'])
top_player2
# Out:
#          full_name     season       Current Club  appearances_overall  \
# 427  Mohamed Salah  2017/2018          Liverpool                   36
# 223     Harry Kane  2017/2018  Tottenham Hotspur                   37
#
#      goals_overall  assists_overall  yellow_cards_overall  red_cards_overall
# 427             32               10                     1                  0
# 223             30                2                     5                  0

# %%
top_player2.index=["Mohamed Salah", "Harry Kane"]
plt.figure(figsize=(20,18))
top_player2.plot(kind='bar')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5),fontsize=13)
plt.title("Top 2 Players depending on the Overall goals from 2017-2018",weight='bold')
plt.xlabel("Players",weight='bold')
plt.ylabel("Points",weight='bold')
plt.savefig("Top 2 Players depending on the Overall goals from 2017-2018.jpg")
  
# Saving figure by changing parameter values
plt.savefig("Top 2 Players depending on the Overall goals from 2017-2018", bbox_inches="tight",
            pad_inches=0.3, transparent=False)

# %%
players3 = pd.read_csv('england-premier-league-players-2018-to-2019-stats (2).csv')
players3
# Out:
#                  full_name  age   birthday birthday_GMT          league  \
# 0          Aaron Cresswell   32  629683200   12/15/1989  Premier League
# 1             Aaron Lennon   34  545529600    4/16/1987  Premier League
# 2               Aaron Mooy   31  653356800    9/15/1990  Premier League
# 3             Aaron Ramsey   31  662169600   12/26/1990  Premier League
# 4               Aaron Rowe   21  968284800     9/7/2000  Premier League
# ..                     ...  ...        ...          ...             ...
# 567        Youri Tielemans   24  862963200     5/7/1997  Premier League
# 568          Yves Bissouma   25  841363200    8/30/1996  Premier League
# 569       Zechariah Medley   21  962928000     7/7/2000  Premier League
# 570  Zeze Steven Sessegnon   21  958608000    5/18/2000  Premier League
# 571       Łukasz Fabiański   36  482630400    4/18/1985  Premier League
#
#         season    position            Current Club  minutes_played_overall  \
# 0    2018/2019    Defender         West Ham United                    1589
# 1    2018/2019  Midfielder                 Burnley                    1217
# 2    2018/2019  Midfielder       Huddersfield Town                    2327
# 3    2018/2019  Midfielder                 Arsenal                    1327
# 4    2018/2019     Forward       Huddersfield Town                      69
# ..         ...         ...                     ...                     ...
# 567  2018/2019  Midfielder          Leicester City                    1092
# 568  2018/2019  Midfielder  Brighton & Hove Albion                    1769
# 569  2018/2019    Defender                 Arsenal                       0
# 570  2018/2019    Defender                  Fulham                       0
# 571  2018/2019  Goalkeeper         West Ham United                    3420
#
#      minutes_played_home  ...  conceded_per_90_overall  \
# 0                    888  ...                     1.25
# 1                    487  ...                     1.48
# 2                   1190  ...                     1.78
# 3                    689  ...                     0.81
# 4                     14  ...                     1.30
# ..                   ...  ...                      ...
# 567                  575  ...                     1.07
# 568                  747  ...                     1.53
# 569                    0  ...                     0.00
# 570                    0  ...                     0.00
# 571                 1710  ...                     1.26
#
#     min_per_conceded_overall  min_per_match  min_per_card_overall  \
# 0                         72             79                  1589
# 1                         61             76                  1217
# 2                         51             80                   582
# 3                        111             47                     0
# 4                         69             35                     0
# ..                       ...            ...                   ...
# 567                       84             84                   546
# 568                       59             63                   354
# 569                        0              0                     0
# 570                        0              0                     0
# 571                       71             90                     0
#
#      min_per_assist_overall  cards_per_90_overall  \
# 0                      1589                  0.06
# 1                      1217                  0.07
# 2                      2327                  0.15
# 3                       221                  0.00
# 4                         0                  0.00
# ..                      ...                   ...
# 567                     273                  0.16
# 568                       0                  0.25
# 569                       0                  0.00
# 570                       0                  0.00
# 571                       0                  0.00
#
#      rank_in_league_top_attackers  rank_in_league_top_midfielders  \
# 0                             290                             191
# 1                             196                             187
# 2                             144                             233
# 3                              69                               8
# 4                              -1                              -1
# ..                            ...                             ...
# 567                            80                              13
# 568                           402                             293
# 569                            -1                              -1
# 570                            -1                              -1
# 571                           391                             343
#
#      rank_in_league_top_defenders  rank_in_club_top_scorer
# 0                              80                       20
# 1                              -1                       10
# 2                              -1                        3
# 3                              -1                        5
# 4                              -1                       31
# ..                            ...                      ...
# 567                            -1                        4
# 568                            -1                       17
# 569                            -1                       -1
# 570                            -1                       -1
# 571                            81                       19
#
# [572 rows x 47 columns]

# %%
players3.drop(['birthday', 'birthday_GMT','nationality' ,'minutes_played_overall', 'minutes_played_home', 'minutes_played_away',
             'goals_away','assists_away','goals_per_90_home','min_per_goal_overall','age','position','league','rank_in_league_top_midfielders',
             'appearances_home','appearances_away','goals_home','assists_home', 'penalty_goals','penalty_misses',
             'conceded_overall','conceded_home','conceded_away','goals_involved_per_90_overall',
             'assists_per_90_overall','goals_per_90_overall','goals_per_90_away','conceded_per_90_overall',
             'min_per_conceded_overall','min_per_match','min_per_card_overall','min_per_assist_overall',
             'cards_per_90_overall','rank_in_league_top_attackers','rank_in_league_top_defenders',
             'rank_in_club_top_scorer','clean_sheets_overall','clean_sheets_home','clean_sheets_away'], axis=1, inplace=True)

# %%
players3
# Out:
#                  full_name     season            Current Club  \
# 0          Aaron Cresswell  2018/2019         West Ham United
# 1             Aaron Lennon  2018/2019                 Burnley
# 2               Aaron Mooy  2018/2019       Huddersfield Town
# 3             Aaron Ramsey  2018/2019                 Arsenal
# 4               Aaron Rowe  2018/2019       Huddersfield Town
# ..                     ...        ...                     ...
# 567        Youri Tielemans  2018/2019          Leicester City
# 568          Yves Bissouma  2018/2019  Brighton & Hove Albion
# 569       Zechariah Medley  2018/2019                 Arsenal
# 570  Zeze Steven Sessegnon  2018/2019                  Fulham
# 571       Łukasz Fabiański  2018/2019         West Ham United
#
#      appearances_overall  goals_overall  assists_overall  \
# 0                     20              0                1
# 1                     16              1                1
# 2                     29              3                1
# 3                     28              4                6
# 4                      2              0                0
# ..                   ...            ...              ...
# 567                   13              3                4
# 568                   28              0                0
# 569                    0              0                0
# 570                    0              0                0
# 571                   38              0                0
#
#      yellow_cards_overall  red_cards_overall
# 0                       1                  0
# 1                       1                  0
# 2                       4                  0
# 3                       0                  0
# 4                       0                  0
# ..                    ...                ...
# 567                     2                  0
# 568                     5                  0
# 569                     0                  0
# 570                     0                  0
# 571                     0                  0
#
# [572 rows x 8 columns]

# %%
top_player3 = players3.nlargest(2,['goals_overall'])
top_player3
# Out:
#                      full_name     season Current Club  appearances_overall  \
# 411              Mohamed Salah  2018/2019    Liverpool                   38
# 455  Pierre-Emerick Aubameyang  2018/2019      Arsenal                   36
#
#      goals_overall  assists_overall  yellow_cards_overall  red_cards_overall
# 411             22                8                     1                  0
# 455             22                5                     0                  0

# %%
top_player3.index=["Mohamed Salah", "Pierre-Emerick Aubameyang"]
plt.figure(figsize=(20,18))
top_player3.plot(kind='bar')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5),fontsize=13)
plt.title("Top 2 Players depending on the Overall goals from 2018-2019",weight='bold')
plt.xlabel("Players",weight='bold')
plt.ylabel("Points",weight='bold')
plt.savefig("Top 2 Players depending on the Overall goals from 2018-2019.jpg")
  
# Saving figure by changing parameter values
plt.savefig("Top 2 Players depending on the Overall goals from 2018-2019", bbox_inches="tight",
            pad_inches=0.3, transparent=False)

# %%
players4 = pd.read_csv('england-premier-league-players-2019-to-2020-stats.csv')
players4
# Out:
#                   full_name  age   birthday birthday_GMT          league  \
# 0    Aaron Anthony Connolly   21  949017600    1/28/2000  Premier League
# 1           Aaron Cresswell   32  629683200   12/15/1989  Premier League
# 2              Aaron Lennon   34  545529600    4/16/1987  Premier League
# 3                Aaron Mooy   31  653356800    9/15/1990  Premier League
# 4            Aaron Ramsdale   23  895104000    5/14/1998  Premier League
# ..                      ...  ...        ...          ...             ...
# 610         Youri Tielemans   24  862963200     5/7/1997  Premier League
# 611           Yves Bissouma   25  841363200    8/30/1996  Premier League
# 612        Zechariah Medley   21  962928000     7/7/2000  Premier League
# 613   Ørjan Håskjold Nyland   31  652924800    9/10/1990  Premier League
# 614        Łukasz Fabiański   36  482630400    4/18/1985  Premier League
#
#         season    position            Current Club  minutes_played_overall  \
# 0    2019/2020     Forward  Brighton & Hove Albion                    1262
# 1    2019/2020    Defender         West Ham United                    2730
# 2    2019/2020  Midfielder                 Burnley                     485
# 3    2019/2020  Midfielder  Brighton & Hove Albion                    2090
# 4    2019/2020  Goalkeeper         AFC Bournemouth                    3330
# ..         ...         ...                     ...                     ...
# 610  2019/2020  Midfielder          Leicester City                    2834
# 611  2019/2020  Midfielder  Brighton & Hove Albion                    1263
# 612  2019/2020    Defender                 Arsenal                       0
# 613  2019/2020  Goalkeeper             Aston Villa                     537
# 614  2019/2020  Goalkeeper         West Ham United                    2119
#
#      minutes_played_home  ...  conceded_per_90_overall  \
# 0                    592  ...                     1.50
# 1                   1395  ...                     1.62
# 2                    225  ...                     2.60
# 3                   1010  ...                     1.29
# 4                   1620  ...                     1.65
# ..                   ...  ...                      ...
# 610                 1433  ...                     1.08
# 611                  636  ...                     1.28
# 612                    0  ...                     0.00
# 613                  360  ...                     2.01
# 614                 1170  ...                     1.40
#
#     min_per_conceded_overall  min_per_match  min_per_card_overall  \
# 0                         60             53                     0
# 1                         56             88                   390
# 2                         35             30                   121
# 3                         70             67                   697
# 4                         55             90                     0
# ..                       ...            ...                   ...
# 610                       83             77                  1417
# 611                       70             57                   316
# 612                        0              0                     0
# 613                       45             77                     0
# 614                       64             85                  2119
#
#      min_per_assist_overall  cards_per_90_overall  \
# 0                      1262                  0.00
# 1                         0                  0.23
# 2                         0                  0.74
# 3                      1045                  0.13
# 4                      3330                  0.00
# ..                      ...                   ...
# 610                     472                  0.06
# 611                       0                  0.29
# 612                       0                  0.00
# 613                       0                  0.00
# 614                       0                  0.04
#
#      rank_in_league_top_attackers  rank_in_league_top_midfielders  \
# 0                              89                             172
# 1                             151                             260
# 2                             320                             402
# 3                             164                             140
# 4                             362                             248
# ..                            ...                             ...
# 610                           159                              64
# 611                           188                             265
# 612                            -1                              -1
# 613                           311                             331
# 614                           341                             271
#
#      rank_in_league_top_defenders  rank_in_club_top_scorer
# 0                              -1                        3
# 1                             129                        6
# 2                              -1                       17
# 3                              -1                        8
# 4                             135                       19
# ..                            ...                      ...
# 610                            -1                        8
# 611                            -1                       13
# 612                            -1                       -1
# 613                           161                       18
# 614                           109                       20
#
# [615 rows x 47 columns]

# %%
players4.drop(['birthday', 'birthday_GMT','nationality' ,'minutes_played_overall', 'minutes_played_home', 'minutes_played_away',
             'goals_away','assists_away','goals_per_90_home','min_per_goal_overall','age','position','league','rank_in_league_top_midfielders',
             'appearances_home','appearances_away','goals_home','assists_home', 'penalty_goals','penalty_misses',
             'conceded_overall','conceded_home','conceded_away','goals_involved_per_90_overall',
             'assists_per_90_overall','goals_per_90_overall','goals_per_90_away','conceded_per_90_overall',
             'min_per_conceded_overall','min_per_match','min_per_card_overall','min_per_assist_overall',
             'cards_per_90_overall','rank_in_league_top_attackers','rank_in_league_top_defenders',
             'rank_in_club_top_scorer','clean_sheets_overall','clean_sheets_home','clean_sheets_away'], axis=1, inplace=True)

# %%
players4
# Out:
#                   full_name     season            Current Club  \
# 0    Aaron Anthony Connolly  2019/2020  Brighton & Hove Albion
# 1           Aaron Cresswell  2019/2020         West Ham United
# 2              Aaron Lennon  2019/2020                 Burnley
# 3                Aaron Mooy  2019/2020  Brighton & Hove Albion
# 4            Aaron Ramsdale  2019/2020         AFC Bournemouth
# ..                      ...        ...                     ...
# 610         Youri Tielemans  2019/2020          Leicester City
# 611           Yves Bissouma  2019/2020  Brighton & Hove Albion
# 612        Zechariah Medley  2019/2020                 Arsenal
# 613   Ørjan Håskjold Nyland  2019/2020             Aston Villa
# 614        Łukasz Fabiański  2019/2020         West Ham United
#
#      appearances_overall  goals_overall  assists_overall  \
# 0                     24              3                1
# 1                     31              3                0
# 2                     16              0                0
# 3                     31              2                2
# 4                     37              0                1
# ..                   ...            ...              ...
# 610                   37              3                6
# 611                   22              1                0
# 612                    0              0                0
# 613                    7              0                0
# 614                   25              0                0
#
#      yellow_cards_overall  red_cards_overall
# 0                       0                  0
# 1                       7                  0
# 2                       4                  0
# 3                       3                  1
# 4                       0                  0
# ..                    ...                ...
# 610                     2                  0
# 611                     4                  0
# 612                     0                  0
# 613                     0                  0
# 614                     1                  0
#
# [615 rows x 8 columns]

# %%
top_player4 = players4.nlargest(2,['goals_overall'])
top_player4
# Out:
#                     full_name     season    Current Club  appearances_overall  \
# 275               Jamie Vardy  2019/2020  Leicester City                   35
# 138  Daniel William John Ings  2019/2020     Southampton                   38
#
#      goals_overall  assists_overall  yellow_cards_overall  red_cards_overall
# 275             23                5                     2                  0
# 138             22                2                     3                  0

# %%
top_player4.index=["Jamie Vardy", "Daniel William John Ings"]
plt.figure(figsize=(20,18))
top_player4.plot(kind='bar')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5),fontsize=13)
plt.title("Top 2 Players depending on the Overall goals from 2019-2020",weight='bold')
plt.xlabel("Players",weight='bold')
plt.ylabel("Points",weight='bold')
plt.savefig("Top 2 Players depending on the Overall goals from 2019-2020.jpg")
  
# Saving figure by changing parameter values
plt.savefig("Top 2 Players depending on the Overall goals from 2019-2020", bbox_inches="tight",
            pad_inches=0.3, transparent=False)

# %%
Merging_Data = pd.concat([top_player,top_player1,top_player2,top_player3,top_player4])
Merging_Data
# Out:
#                                            full_name     season  \
# Harry Kane                                Harry Kane  2015/2016
# Jamie Vardy                              Jamie Vardy  2015/2016
# Harry Kane                                Harry Kane  2016/2017
# Romelu Lukaku                          Romelu Lukaku  2016/2017
# Mohamed Salah                          Mohamed Salah  2017/2018
# Harry Kane                                Harry Kane  2017/2018
# Mohamed Salah                          Mohamed Salah  2018/2019
# Pierre-Emerick Aubameyang  Pierre-Emerick Aubameyang  2018/2019
# Jamie Vardy                              Jamie Vardy  2019/2020
# Daniel William John Ings    Daniel William John Ings  2019/2020
#
#                                 Current_Club  appearances_overall  \
# Harry Kane                 Tottenham Hotspur                   38
# Jamie Vardy                   Leicester City                   36
# Harry Kane                 Tottenham Hotspur                   30
# Romelu Lukaku                        Everton                   37
# Mohamed Salah                            NaN                   36
# Harry Kane                               NaN                   37
# Mohamed Salah                            NaN                   38
# Pierre-Emerick Aubameyang                NaN                   36
# Jamie Vardy                              NaN                   35
# Daniel William John Ings                 NaN                   38
#
#                            goals_overall  assists_overall  \
# Harry Kane                            25                1
# Jamie Vardy                           24                6
# Harry Kane                            29                7
# Romelu Lukaku                         25                6
# Mohamed Salah                         32               10
# Harry Kane                            30                2
# Mohamed Salah                         22                8
# Pierre-Emerick Aubameyang             22                5
# Jamie Vardy                           23                5
# Daniel William John Ings              22                2
#
#                            yellow_cards_overall  red_cards_overall  \
# Harry Kane                                    5                  0
# Jamie Vardy                                   7                  1
# Harry Kane                                    3                  0
# Romelu Lukaku                                 3                  0
# Mohamed Salah                                 1                  0
# Harry Kane                                    5                  0
# Mohamed Salah                                 1                  0
# Pierre-Emerick Aubameyang                     0                  0
# Jamie Vardy                                   2                  0
# Daniel William John Ings                      3                  0
#
#                                 Current Club
# Harry Kane                               NaN
# Jamie Vardy                              NaN
# Harry Kane                               NaN
# Romelu Lukaku                            NaN
# Mohamed Salah                      Liverpool
# Harry Kane                 Tottenham Hotspur
# Mohamed Salah                      Liverpool
# Pierre-Emerick Aubameyang            Arsenal
# Jamie Vardy                   Leicester City
# Daniel William John Ings         Southampton

# %%
Merging_Data.index=(["Harry Kane", "Jamie Vardy","Harry Kane", "Romelu Lukaku","Mohamed Salah", "Harry Kane",
                   "Mohamed Salah", "Pierre-Emerick Aubameyang","Jamie Vardy", "Daniel William John Ings"])
plt.rcParams.update({'font.size': 30})
plt.rcParams["figure.figsize"] = (30,15)
Merging_Data.plot(kind='bar',figsize=(20, 15))
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5),fontsize=20)
plt.title("Top Players depending on the Overall goals from 2015-2020",weight='bold',size=20)
plt.xlabel("Players",weight='bold',size=20)
plt.ylabel("Points",weight='bold',size=20)
plt.savefig("Top Players depending on the Overall goals from 2015-2020.jpg")
  
# Saving figure by changing parameter values
plt.savefig("Top Players depending on the Overall goals from 2015-2020", bbox_inches="tight",
            pad_inches=0.3, transparent=False)
